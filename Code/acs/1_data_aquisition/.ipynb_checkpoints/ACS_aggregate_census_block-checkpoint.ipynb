# %%
import os
import pandas as pd

import zipfile #i am not giving it a name cause i intend to use it only once

# %%
path = '../../../Data/ACS/5y2013_NYS/NewYork/'

# %%
def getFiles(folder, format, full=True, filtr=None):
    for f in os.listdir(folder):
        if f.endswith(format):
            if filtr==None or filtr not in f:
                if full:
                    yield os.path.join(folder, f)
                else:
                    yield f

# %%
zips = list(getFiles(path, '.zip'))
zips[:10]
# Out:
# ['../../../Data/ACS/5y2013_NYS/NewYork/20135ny0001000.zip',
#  '../../../Data/ACS/5y2013_NYS/NewYork/20135ny0002000.zip',
#  '../../../Data/ACS/5y2013_NYS/NewYork/20135ny0003000.zip',
#  '../../../Data/ACS/5y2013_NYS/NewYork/20135ny0004000.zip',
#  '../../../Data/ACS/5y2013_NYS/NewYork/20135ny0005000.zip',
#  '../../../Data/ACS/5y2013_NYS/NewYork/20135ny0006000.zip',
#  '../../../Data/ACS/5y2013_NYS/NewYork/20135ny0007000.zip',
#  '../../../Data/ACS/5y2013_NYS/NewYork/20135ny0008000.zip',
#  '../../../Data/ACS/5y2013_NYS/NewYork/20135ny0009000.zip',
#  '../../../Data/ACS/5y2013_NYS/NewYork/20135ny0010000.zip']

# %%
def estimates(f):
    return 'e' + f.replace('.zip','.txt')

# %%
cols = [
'FILEID',
'FILETYPE',
'STUSAB',
'CHARITER',
'SEQUENCE',
'LOGRECNO',
]

# %%
def getTable(fname):
    zf = zipfile.ZipFile(fname)
    df = pd.read_csv(zf.open(estimates(fname.split('/')[-1])), 
                     dtype={5:str, 4:str},
                     header=None, low_memory=False)
    seq = df.iloc[1,4]

    df.columns = cols + ['%s_%d' % (seq , i+1) for i in xrange(df.shape[1] - 6)]
    return df.iloc[:,5:].set_index('LOGRECNO')

# %%
t1 = getTable(zips[0])

# %%
t1.head()
# Out:
#           0001_1  0001_2
# LOGRECNO
# 0003385      186      95
# 0003386      213     129
# 0003387      282     127
# 0003388      236      98
# 0003389      218     117

# %%
def aggTables(folder):
    
    tables =(getTable(f) for f in getFiles(folder, '.zip'))
    return pd.concat(tables,1)

# %%
mdf = aggTables(path)

mdf.head(3)
# Out:
#           0001_1  0001_2  0002_1  0002_2  0002_3  0002_4  0002_5  0002_6  \
# LOGRECNO
# 0003385      186      95    2163     859      59      40      77      20
# 0003386      213     129    5335    2671     329     149     330     217
# 0003387      282     127    6077    2859     130     253     451     117
#
#           0002_7  0002_8   ...     0122_49  0122_50  0122_51  0122_52  \
# LOGRECNO                   ...
# 0003385       58       0   ...        1876     2139      259     1880
# 0003386       81      56   ...        5139     5319      256     5063
# 0003387       79      72   ...        5626     5865      321     5544
#
#           0122_53  0122_54  0122_55  0122_56  0122_57  0122_58
# LOGRECNO
# 0003385      2139      275     1864     2139      275     1864
# 0003386      5319      270     5049     5319      256     5063
# 0003387      5865      437     5428     5865      443     5422
#
# [3 rows x 22711 columns]

# %%
## rows with NAN
mdf[mdf.isnull().any(axis=1)]
# Out:
#           0001_1  0001_2  0002_1  0002_2  0002_3  0002_4  0002_5  0002_6  \
# LOGRECNO
# 0003385      186      95    2163     859      59      40      77      20
# 0003386      213     129    5335    2671     329     149     330     217
# 0003387      282     127    6077    2859     130     253     451     117
# 0003388      236      98    2380     856      31       0       7      26
# 0003389      218     117    4338    1739      58      32      11      48
# 0003390      NaN     NaN    4932    2563       0       0       0      34
# 0003391      214     101    3612    1862     234      68      59      63
# 0003392      478      96    3721    1741      42      18      18      36
# 0003393      233      98    4356    2456     149     182     176      89
# 0003394      254     139    3744    1792     222     261     145      72
# 0003395      156      92    2186    1009      51     126      64      45
# 0003396      113      75    1249     832      31       0      56      13
# ...

# %%
mdf.to_csv('../../Data/raw_full_5yNY.csv')

# %%
mdf.shape
# Out:
# (20381, 22711)

# %%
# pumas = pd.read_csv('../../Data/geo_id/pumas.csv', index_col=0, dtype='str')[[4, 49]]
bgs = pd.read_csv('../../Data/geo_id/bg.csv', index_col=0, dtype='str')[[4, 49]]

# %%
mdfCB = mdf[mdf.index.isin(bgs['4'].tolist())]
mdfCB.shape
# Out:
# (15463, 22711)

# %%
mdfCB.to_csv('../../Data/raw_block_group_5yNY.csv')

# %%
pd.DataFrame(mdf.columns).to_csv('../../Data/blocks_attributes.csv')
