# %%
import pandas as pd

# %%
def process_lookup(path):
    df = pd.read_csv(path)
    df['Q'] = df[pd.notnull(df['Total Cells in Table'])]['Table Title']
    df['Q'] = df['Q'].fillna(method='ffill')
    df = df[df['Line Number'].str.strip().str.len() >0]
    df['A'] = df[df['Table Title'].str.endswith(':')]['Table Title']
    df['A'] = df.groupby(['Table ID', 'Q'])['A'].transform(lambda group: group.ffill())
    df['Column'] = df['Sequence Number'].astype(str) +'_' + df['Line Number'].astype(str)
    return df[['Table ID', 'Column', 'Q', 'A','Table Title']]

# %%
pa = process_lookup('../../Data/raw_aggData/lookup_table20131Y.csv')
ba = process_lookup('../../Data/raw_aggData/lookup_table20135Y.csv')

# %%
pa
# Out:
#       Table ID   Column                                                  Q  \
# 2       B00001      1_1          UNWEIGHTED SAMPLE COUNT OF THE POPULATION
# 5       B00002      1_1                    UNWEIGHTED SAMPLE HOUSING UNITS
# 8       B01001      2_1                                         SEX BY AGE
# 9       B01001      2_2                                         SEX BY AGE
# 10      B01001      2_3                                         SEX BY AGE
# 11      B01001      2_4                                         SEX BY AGE
# 12      B01001      2_5                                         SEX BY AGE
# 13      B01001      2_6                                         SEX BY AGE
# 14      B01001      2_7                                         SEX BY AGE
# 15      B01001      2_8                                         SEX BY AGE
# 16      B01001      2_9                                         SEX BY AGE
# 17      B01001     2_10                                         SEX BY AGE
# 18      B01001     2_11                                         SEX BY AGE
# 19      B01001     2_12                                         SEX BY AGE
# 20      B01001     2_13                                         SEX BY AGE
# 21      B01001     2_14                                         SEX BY AGE
# 22      B01001     2_15                                         SEX BY AGE
# 23      B01001     2_16                                         SEX BY AGE
# 24      B01001     2_17                                         SEX BY AGE
# 25      B01001     2_18                                         SEX BY AGE
# 26      B01001     2_19                                         SEX BY AGE
# 27      B01001     2_20                                         SEX BY AGE
# 28      B01001     2_21                                         SEX BY AGE
# 29      B01001     2_22                                         SEX BY AGE
# 30      B01001     2_23                                         SEX BY AGE
# 31      B01001     2_24                                         SEX BY AGE
# 32      B01001     2_25                                         SEX BY AGE
# 33      B01001     2_26                                         SEX BY AGE
# 34      B01001     2_27                                         SEX BY AGE
# 35      B01001     2_28                                         SEX BY AGE
# ...        ...      ...                                                ...
# 35630  B992706    170_3                    IMPUTATION OF MEDICARE COVERAGE
# 35633  B992707    170_1  IMPUTATION OF MEDICAID/MEANS-TESTED PUBLIC COV...
# 35634  B992707    170_2  IMPUTATION OF MEDICAID/MEANS-TESTED PUBLIC COV...
# 35635  B992707    170_3  IMPUTATION OF MEDICAID/MEANS-TESTED PUBLIC COV...
# 35638  B992708    170_1     IMPUTATION OF TRICARE/MILITARY HEALTH COVERAGE
# 35639  B992708    170_2     IMPUTATION OF TRICARE/MILITARY HEALTH COVERAGE
# 35640  B992708    170_3     IMPUTATION OF TRICARE/MILITARY HEALTH COVERAGE
# 35643  B992709    170_1                       IMPUTATION OF VA HEALTH CARE
# 35644  B992709    170_2                       IMPUTATION OF VA HEALTH CARE
# 35645  B992709    170_3                       IMPUTATION OF VA HEALTH CARE
# 35648   B99281    170_1            IMPUTATION OF HOUSEHOLD INTERNET ACCESS
# 35649   B99281    170_2            IMPUTATION OF HOUSEHOLD INTERNET ACCESS
# 35650   B99281    170_3            IMPUTATION OF HOUSEHOLD INTERNET ACCESS
# 35653   B99282    170_1              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35654   B99282  170_1.5              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35655   B99282    170_2              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35656   B99282    170_3              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35657   B99282  170_3.5              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35658   B99282    170_4              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35659   B99282    170_5              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35660   B99282  170_5.5              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35661   B99282    170_6              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35662   B99282    170_7              IMPUTATION OF HOUSEHOLD COMPUTER TYPE
# 35665   B99283    170_1  IMPUTATION OF HOUSEHOLD INTERNET SUBSCRIPTION ...
# 35666   B99283  170_1.5  IMPUTATION OF HOUSEHOLD INTERNET SUBSCRIPTION ...
# 35667   B99283    170_2  IMPUTATION OF HOUSEHOLD INTERNET SUBSCRIPTION ...
# 35668   B99283    170_3  IMPUTATION OF HOUSEHOLD INTERNET SUBSCRIPTION ...
# 35669   B99283    170_4  IMPUTATION OF HOUSEHOLD INTERNET SUBSCRIPTION ...
# 35670   B99283    170_5  IMPUTATION OF HOUSEHOLD INTERNET SUBSCRIPTION ...
# 35671   B99283    170_6  IMPUTATION OF HOUSEHOLD INTERNET SUBSCRIPTION ...
#
#                         A                                        Table Title
# 2                     NaN                                              Total
# 5                     NaN                                              Total
# 8                  Total:                                             Total:
# 9                   Male:                                              Male:
# 10                  Male:                                      Under 5 years
# 11                  Male:                                       5 to 9 years
# 12                  Male:                                     10 to 14 years
# 13                  Male:                                     15 to 17 years
# 14                  Male:                                    18 and 19 years
# 15                  Male:                                           20 years
# 16                  Male:                                           21 years
# 17                  Male:                                     22 to 24 years
# 18                  Male:                                     25 to 29 years
# 19                  Male:                                     30 to 34 years
# 20                  Male:                                     35 to 39 years
# 21                  Male:                                     40 to 44 years
# 22                  Male:                                     45 to 49 years
# 23                  Male:                                     50 to 54 years
# 24                  Male:                                     55 to 59 years
# 25                  Male:                                    60 and 61 years
# 26                  Male:                                     62 to 64 years
# 27                  Male:                                    65 and 66 years
# 28                  Male:                                     67 to 69 years
# 29                  Male:                                     70 to 74 years
# 30                  Male:                                     75 to 79 years
# 31                  Male:                                     80 to 84 years
# 32                  Male:                                  85 years and over
# 33                Female:                                            Female:
# 34                Female:                                      Under 5 years
# 35                Female:                                       5 to 9 years
# ...                   ...                                                ...
# 35630              Total:                                        Not imputed
# 35633              Total:                                             Total:
# 35634              Total:                                            Imputed
# 35635              Total:                                        Not imputed
# 35638              Total:                                             Total:
# 35639              Total:                                            Imputed
# 35640              Total:                                        Not imputed
# 35643              Total:                                             Total:
# 35644              Total:                                            Imputed
# 35645              Total:                                        Not imputed
# 35648              Total:                                             Total:
# 35649              Total:                                            Imputed
# 35650              Total:                                        Not imputed
# 35653              Total:                                             Total:
# 35654  Desktop or laptop:                                 Desktop or laptop:
# 35655  Desktop or laptop:                                            Imputed
# 35656  Desktop or laptop:                                        Not imputed
# 35657  Handheld computer:                                 Handheld computer:
# 35658  Handheld computer:                                            Imputed
# 35659  Handheld computer:                                        Not imputed
# 35660     Other computer:                                    Other computer:
# 35661     Other computer:                                            Imputed
# 35662     Other computer:                                        Not imputed
# 35665              Total:                                             Total:
# 35666            Imputed:                                           Imputed:
# 35667            Imputed:                                            Dial-up
# 35668            Imputed:                                                DSL
# 35669            Imputed:  Cable modem, fiber-optic, satellite internet s...
# 35670            Imputed:                                   Mobile broadband
# 35671            Imputed:                                        Not imputed
#
# [32902 rows x 5 columns]

# %%
ba
# Out:
#       Table ID Column                                                  Q  \
# 2       B00001    1_1          UNWEIGHTED SAMPLE COUNT OF THE POPULATION
# 5       B00002    1_1                    UNWEIGHTED SAMPLE HOUSING UNITS
# 8       B01001    2_1                                         SEX BY AGE
# 9       B01001    2_2                                         SEX BY AGE
# 10      B01001    2_3                                         SEX BY AGE
# 11      B01001    2_4                                         SEX BY AGE
# 12      B01001    2_5                                         SEX BY AGE
# 13      B01001    2_6                                         SEX BY AGE
# 14      B01001    2_7                                         SEX BY AGE
# 15      B01001    2_8                                         SEX BY AGE
# 16      B01001    2_9                                         SEX BY AGE
# 17      B01001   2_10                                         SEX BY AGE
# 18      B01001   2_11                                         SEX BY AGE
# 19      B01001   2_12                                         SEX BY AGE
# 20      B01001   2_13                                         SEX BY AGE
# 21      B01001   2_14                                         SEX BY AGE
# 22      B01001   2_15                                         SEX BY AGE
# 23      B01001   2_16                                         SEX BY AGE
# 24      B01001   2_17                                         SEX BY AGE
# 25      B01001   2_18                                         SEX BY AGE
# 26      B01001   2_19                                         SEX BY AGE
# 27      B01001   2_20                                         SEX BY AGE
# 28      B01001   2_21                                         SEX BY AGE
# 29      B01001   2_22                                         SEX BY AGE
# 30      B01001   2_23                                         SEX BY AGE
# 31      B01001   2_24                                         SEX BY AGE
# 32      B01001   2_25                                         SEX BY AGE
# 33      B01001   2_26                                         SEX BY AGE
# 34      B01001   2_27                                         SEX BY AGE
# 35      B01001   2_28                                         SEX BY AGE
# ...        ...    ...                                                ...
# 24909   B99259  122_1                  IMPUTATION OF PLUMBING FACILITIES
# 24910   B99259  122_2                  IMPUTATION OF PLUMBING FACILITIES
# 24911   B99259  122_3                  IMPUTATION OF PLUMBING FACILITIES
# 24914  B992701  122_1            IMPUTATION OF HEALTH INSURANCE COVERAGE
# 24915  B992701  122_2            IMPUTATION OF HEALTH INSURANCE COVERAGE
# 24916  B992701  122_3            IMPUTATION OF HEALTH INSURANCE COVERAGE
# 24919  B992702  122_1             IMPUTATION OF PRIVATE HEALTH INSURANCE
# 24920  B992702  122_2             IMPUTATION OF PRIVATE HEALTH INSURANCE
# 24921  B992702  122_3             IMPUTATION OF PRIVATE HEALTH INSURANCE
# 24924  B992703  122_1              IMPUTATION OF PUBLIC HEALTH INSURANCE
# 24925  B992703  122_2              IMPUTATION OF PUBLIC HEALTH INSURANCE
# 24926  B992703  122_3              IMPUTATION OF PUBLIC HEALTH INSURANCE
# 24929  B992704  122_1      IMPUTATION OF EMPLOYER-BASED HEALTH INSURANCE
# 24930  B992704  122_2      IMPUTATION OF EMPLOYER-BASED HEALTH INSURANCE
# 24931  B992704  122_3      IMPUTATION OF EMPLOYER-BASED HEALTH INSURANCE
# 24934  B992705  122_1     IMPUTATION OF DIRECT-PURCHASE HEALTH INSURANCE
# 24935  B992705  122_2     IMPUTATION OF DIRECT-PURCHASE HEALTH INSURANCE
# 24936  B992705  122_3     IMPUTATION OF DIRECT-PURCHASE HEALTH INSURANCE
# 24939  B992706  122_1                    IMPUTATION OF MEDICARE COVERAGE
# 24940  B992706  122_2                    IMPUTATION OF MEDICARE COVERAGE
# 24941  B992706  122_3                    IMPUTATION OF MEDICARE COVERAGE
# 24944  B992707  122_1  IMPUTATION OF MEDICAID/MEANS-TESTED PUBLIC COV...
# 24945  B992707  122_2  IMPUTATION OF MEDICAID/MEANS-TESTED PUBLIC COV...
# 24946  B992707  122_3  IMPUTATION OF MEDICAID/MEANS-TESTED PUBLIC COV...
# 24949  B992708  122_1     IMPUTATION OF TRICARE/MILITARY HEALTH COVERAGE
# 24950  B992708  122_2     IMPUTATION OF TRICARE/MILITARY HEALTH COVERAGE
# 24951  B992708  122_3     IMPUTATION OF TRICARE/MILITARY HEALTH COVERAGE
# 24954  B992709  122_1                       IMPUTATION OF VA HEALTH CARE
# 24955  B992709  122_2                       IMPUTATION OF VA HEALTH CARE
# 24956  B992709  122_3                       IMPUTATION OF VA HEALTH CARE
#
#              A                                        Table Title
# 2          NaN                                              Total
# 5          NaN                                              Total
# 8       Total:                                             Total:
# 9        Male:                                              Male:
# 10       Male:                                      Under 5 years
# 11       Male:                                       5 to 9 years
# 12       Male:                                     10 to 14 years
# 13       Male:                                     15 to 17 years
# 14       Male:                                    18 and 19 years
# 15       Male:                                           20 years
# 16       Male:                                           21 years
# 17       Male:                                     22 to 24 years
# 18       Male:                                     25 to 29 years
# 19       Male:                                     30 to 34 years
# 20       Male:                                     35 to 39 years
# 21       Male:                                     40 to 44 years
# 22       Male:                                     45 to 49 years
# 23       Male:                                     50 to 54 years
# 24       Male:                                     55 to 59 years
# 25       Male:                                    60 and 61 years
# 26       Male:                                     62 to 64 years
# 27       Male:                                    65 and 66 years
# 28       Male:                                     67 to 69 years
# 29       Male:                                     70 to 74 years
# 30       Male:                                     75 to 79 years
# 31       Male:                                     80 to 84 years
# 32       Male:                                  85 years and over
# 33     Female:                                            Female:
# 34     Female:                                      Under 5 years
# 35     Female:                                       5 to 9 years
# ...        ...                                                ...
# 24909   Total:                                             Total:
# 24910   Total:                                            Imputed
# 24911   Total:                                        Not imputed
# 24914   Total:                                             Total:
# 24915   Total:         One or more health insurance items imputed
# 24916   Total:                  No health insurance items imputed
# 24919   Total:                                             Total:
# 24920   Total:  One or more private health insurance items imp...
# 24921   Total:          No private health insurance items imputed
# 24924   Total:                                             Total:
# 24925   Total:          One or more public coverage items imputed
# 24926   Total:                   No public coverage items imputed
# 24929   Total:                                             Total:
# 24930   Total:                                            Imputed
# 24931   Total:                                        Not imputed
# 24934   Total:                                             Total:
# 24935   Total:                                            Imputed
# 24936   Total:                                        Not imputed
# 24939   Total:                                             Total:
# 24940   Total:                                            Imputed
# 24941   Total:                                        Not imputed
# 24944   Total:                                             Total:
# 24945   Total:                                            Imputed
# 24946   Total:                                        Not imputed
# 24949   Total:                                             Total:
# 24950   Total:                                            Imputed
# 24951   Total:                                        Not imputed
# 24954   Total:                                             Total:
# 24955   Total:                                            Imputed
# 24956   Total:                                        Not imputed
#
# [22847 rows x 5 columns]

# %% [markdown]
# # Intersecting Table ID's

# %%
len([ x for x in pa['Table ID'].unique().tolist() if x in ba['Table ID'].unique().tolist()])
# Out:
# 1040

# %%
df = pa.merge(ba, how='inner', on=['Table ID','Q', 'A', 'Table Title'])
df.rename(columns={'Column_x':'puma_attr', 'Column_y':'block_attr'}, inplace=1)

# %%
df.shape
# Out:
# (43243, 6)

# %%
df.Q = df.Q.str.lower()
df['Table Title'] = df['Table Title'].str.lower()

# %%
# dropping all imputations
df = df[~df['Q'].str.contains('imputation')]
df.shape
# Out:
# (42803, 6)

# %%
# dropping all samples
df = df[~df['Q'].str.contains('sample')]
df.shape
# Out:
# (42796, 6)

# %%
df['Q_name'] = df.apply(lambda x:'%s_%s_%s_%s' % (x['Table ID'],x['Q'],x['A'],x['Table Title']),axis=1)

# %%
df[df['puma_attr']!=df['block_attr']].head(10)
# Out:
#     Table ID puma_attr                                             Q  \
# 406   B03001       6_1  hispanic or latino origin by specific origin
# 407   B03001       6_2  hispanic or latino origin by specific origin
# 408   B03001       6_3  hispanic or latino origin by specific origin
# 409   B03001       6_4  hispanic or latino origin by specific origin
# 410   B03001       6_5  hispanic or latino origin by specific origin
# 411   B03001       6_6  hispanic or latino origin by specific origin
# 412   B03001       6_7  hispanic or latino origin by specific origin
# 413   B03001       6_8  hispanic or latino origin by specific origin
# 414   B03001       6_9  hispanic or latino origin by specific origin
# 415   B03001      6_10  hispanic or latino origin by specific origin
#
#                        A                     Table Title block_attr  \
# 406               Total:                          total:        5_1
# 407               Total:          not hispanic or latino        5_2
# 408  Hispanic or Latino:             hispanic or latino:        5_3
# 409  Hispanic or Latino:                         mexican        5_4
# 410  Hispanic or Latino:                    puerto rican        5_5
# 411  Hispanic or Latino:                           cuban        5_6
# 412  Hispanic or Latino:  dominican (dominican republic)        5_7
# 413    Central American:               central american:        5_8
# 414    Central American:                     costa rican        5_9
# 415    Central American:                      guatemalan       5_10
#
#                                                 Q_name
# 406  B03001_hispanic or latino origin by specific o...
# 407  B03001_hispanic or latino origin by specific o...
# 408  B03001_hispanic or latino origin by specific o...
# 409  B03001_hispanic or latino origin by specific o...
# 410  B03001_hispanic or latino origin by specific o...
# 411  B03001_hispanic or latino origin by specific o...
# 412  B03001_hispanic or latino origin by specific o...
# 413  B03001_hispanic or latino origin by specific o...
# 414  B03001_hispanic or latino origin by specific o...
# 415  B03001_hispanic or latino origin by specific o...

# %%
r = df[['Q_name', 'puma_attr','block_attr']]
r.reset_index(inplace=1)
r['ourID'] = r['index'].apply(lambda x: 'our%d' % x)
r.drop('index',1, inplace=1)
# Out:
# /Users/casy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/casy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
r['puma_attr'] = r.puma_attr.apply(lambda x: '_'.join((x.split('_')[0].zfill(4), x.split('_')[1])))
r['block_attr'] = r.puma_attr.apply(lambda x: '_'.join((x.split('_')[0].zfill(4), x.split('_')[1])))
# Out:
# /Users/casy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/casy/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
r.head(10)
# Out:
#                                     Q_name puma_attr block_attr  ourID
# 0          B01001_sex by age_Total:_total:    0002_1     0002_1   our2
# 1            B01001_sex by age_Male:_male:    0002_2     0002_2   our3
# 2    B01001_sex by age_Male:_under 5 years    0002_3     0002_3   our4
# 3     B01001_sex by age_Male:_5 to 9 years    0002_4     0002_4   our5
# 4   B01001_sex by age_Male:_10 to 14 years    0002_5     0002_5   our6
# 5   B01001_sex by age_Male:_15 to 17 years    0002_6     0002_6   our7
# 6  B01001_sex by age_Male:_18 and 19 years    0002_7     0002_7   our8
# 7         B01001_sex by age_Male:_20 years    0002_8     0002_8   our9
# 8         B01001_sex by age_Male:_21 years    0002_9     0002_9  our10
# 9   B01001_sex by age_Male:_22 to 24 years   0002_10    0002_10  our11

# %%
r.shape[0] == r['ourID'].unique().shape[0]
# Out:
# True

# %%
r.to_csv('../../Data/raw_aggData/attr_interconn.csv')
